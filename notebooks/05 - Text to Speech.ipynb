# %%
import os
os.chdir('./..')

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from pyht import Client
from pyht.client import TTSOptions
import tempfile
import wave

def text_to_speech(text_to_convert):

    client = Client(
        user_id=os.environ['PYHT_USER_ID'], 
        api_key=os.environ['PYHT_SECRET']
    )


    options = TTSOptions(voice=os.environ['PYHT_VOICE_NARRATOR'])

    with tempfile.NamedTemporaryFile(delete=False, suffix='.wav') as fp:
        with wave.open(fp, 'wb') as wf:
            wf.setnchannels(1)
            wf.setsampwidth(2)
            wf.setframerate(22050)

            for chunk in client.tts(text_to_convert, options):
                wf.writeframes(chunk)

        audio_file_path = fp.name

    return audio_file_path

# %%
text = "You take a deep breath and step into the cave, your senses on high alert. The temperature drops noticeably as you move further inside, and the light from the entrance quickly fades. You fumble in your pack for a torch and light it, casting flickering shadows on the rough stone walls. The passageway narrows, forcing you to proceed single file. As you advance, you notice the ground becoming slick with moisture, making each step treacherous."

# %%
apth = text_to_speech(text)

# %%
import IPython
IPython.display.Audio(apth)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # List of Voices
#
#
# Look here: https://play.ht/ultra-realistic-voices/

# %%
import requests
import json
url = "https://api.play.ht/api/v2/voices"

headers = {
    "accept": "application/json",
    "AUTHORIZATION": os.environ['PYHT_SECRET'], 
    "X-USER-ID": os.environ['PYHT_USER_ID'], 
    
}

response = requests.get(url, headers=headers)
list_of_voices = response.json()
print(json.dumps(response.json(),indent=4))
# Out:
# [
#     {
#         "id": "s3://voice-cloning-zero-shot/d82d246c-148b-457f-9668-37b789520891/adolfosaad/manifest.json",
#         "name": "Adolfo",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/adolfo.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "fast",
#         "texture": "thick",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/a59cb96d-bba8-4e24-81f2-e60b888a0275/charlottenarrativesaad/manifest.json",
#         "name": "Charlotte (Narrative)",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/charlotte+(narrative).wav",
#         "accent": "canadian",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (CA)",
#         "language_code": "en-CA",
#         "loudness": "low",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/3a831d1f-2183-49de-b6d8-33f16b2e9867/dylansaad/manifest.json",
#         "name": "Dylan",
#         "sample": "https://peregrine-results.s3.amazonaws.com/AAc418f41vBRkHNOdi.mp3",
#         "accent": "british",
#         "age": "old",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "gaming",
#         "tempo": "slow",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/f6594c50-e59b-492c-bac2-047d57f8bdd8/susanadvertisingsaad/manifest.json",
#         "name": "Susan (Advertising)",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/susan+(advertising).wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "advertising",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/e5df2eb3-5153-40fa-9f6e-6e27bbb7a38e/original/manifest.json",
#         "name": "Navya",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Navya.wav",
#         "accent": "indian",
#         "age": null,
#         "gender": "female",
#         "language": "English (IN)",
#         "language_code": "en-IN",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/b41d1a8c-2c99-4403-8262-5808bc67c3e0/bentonsaad/manifest.json",
#         "name": "Benton",
#         "sample": "https://peregrine-results.s3.amazonaws.com/fPBgu4E0dT9eMkxIe0.mp3",
#         "accent": "american",
#         "age": "old",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "videos",
#         "tempo": "fast",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/9fc626dc-f6df-4f47-a112-39461e8066aa/oliviaadvertisingsaad/manifest.json",
#         "name": "Olivia (Advertising)",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/olivia+advertising.wav",
#         "accent": "canadian",
#         "age": null,
#         "gender": "female",
#         "language": "English (CA)",
#         "language_code": "en-CA",
#         "loudness": null,
#         "style": "advertising",
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/1afba232-fae0-4b69-9675-7f1aac69349f/delilahsaad/manifest.json",
#         "name": "Delilah",
#         "sample": "https://peregrine-results.s3.amazonaws.com/UlI3kAAfgCOJNP2OMe.mp3",
#         "accent": "american",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "slow",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/9f1ee23a-9108-4538-90be-8e62efc195b6/charlessaad/manifest.json",
#         "name": "Charles",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/charles.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/473c81b1-93ea-4662-9e63-7d65392e5f9b/madisonsaad/manifest.json",
#         "name": "Madison",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/madison.wav",
#         "accent": "irish",
#         "age": "old",
#         "gender": "female",
#         "language": "English (IE)",
#         "language_code": "en-IE",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "slow",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/2879ab87-3775-4992-a228-7e4f551658c2/fredericksaad2/manifest.json",
#         "name": "Frederick",
#         "sample": "https://peregrine-results.s3.amazonaws.com/rixIUBC2k3d0xHY4B2.mp3",
#         "accent": "british",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (GB)",
#         "language_code": "en-GB",
#         "loudness": "low",
#         "style": "narrative",
#         "tempo": "slow",
#         "texture": "thick",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/a540a448-a9ca-446c-9538-d1bae6c506f1/original/manifest.json",
#         "name": "Mason",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Mason.wav",
#         "accent": "american",
#         "age": null,
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/a5cc7dd9-069c-4fe8-9ae7-0c4bae4779c5/micahsaad/manifest.json",
#         "name": "Micah",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/micah.wav",
#         "accent": "british",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/d99d35e6-e625-4fa4-925a-d65172d358e1/adriansaad/manifest.json",
#         "name": "Adrian",
#         "sample": "https://peregrine-results.s3.amazonaws.com/0hjUhtQD61YXtW39OP.mp3",
#         "accent": "american",
#         "age": "old",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "fast",
#         "texture": "thick",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/97580643-b568-4198-aaa4-3e07e4a06c47/original/manifest.json",
#         "name": "Indigo",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Indigo.wav",
#         "accent": "british",
#         "age": null,
#         "gender": "female",
#         "language": "English (GB)",
#         "language_code": "en-GB",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/36e9c53d-ca4e-4815-b5ed-9732be3839b4/samuelsaad/manifest.json",
#         "name": "Samuel",
#         "sample": "https://peregrine-results.s3.amazonaws.com/ww8lf6xg9KAGV6kfyg.mp3",
#         "accent": "american",
#         "age": "old",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "narrative",
#         "tempo": "slow",
#         "texture": "gravelly",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/743575eb-efdc-4c10-b185-a5018148822f/original/manifest.json",
#         "name": "Calvin",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Calvin.wav",
#         "accent": "american",
#         "age": null,
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/7b97b543-7877-41b6-86ee-aa1e0b6c110e/dicksaad/manifest.json",
#         "name": "Dick",
#         "sample": "https://peregrine-results.s3.amazonaws.com/ydgska4ZaIJ3bmRy0t.mp3",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "training",
#         "tempo": "fast",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/34eaa933-62cb-4e32-adb8-c1723ef85097/original/manifest.json",
#         "name": "Amelia",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Amelia.wav",
#         "accent": "british",
#         "age": null,
#         "gender": "female",
#         "language": "English (GB)",
#         "language_code": "en-GB",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/cebaa3cf-d1d5-4625-ba20-03dcca3b379f/sargesaad/manifest.json",
#         "name": "Sarge",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/sarge.wav",
#         "accent": "american",
#         "age": null,
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": "gaming",
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/688d0200-7415-42b4-8726-e2f5693aaac8/williamnarrativesaad/manifest.json",
#         "name": "William (Narrative)",
#         "sample": "https://peregrine-results.s3.amazonaws.com/BRbOe9n93ab1YI2Hot.mp3",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/9a5deeda-3025-49c5-831a-ac98f86f2a37/aprilsaad/manifest.json",
#         "name": "April",
#         "sample": "https://peregrine-results.s3.amazonaws.com/nbrn3tdfuXIxGn8TIl.mp3",
#         "accent": "british",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "slow",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/def0cd31-1b8c-486e-82d2-050a0ea2965d/axelsaad/manifest.json",
#         "name": "Axel",
#         "sample": "https://peregrine-results.s3.amazonaws.com/N5TqVLG8y2deM1e5bQ.mp3",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "fast",
#         "texture": "thick",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/d712cad5-85db-44c6-8ee0-8f4361ed537b/eleanorsaad2/manifest.json",
#         "name": "Eleanor",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/eleanor-2.wav",
#         "accent": "british",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "advertising",
#         "tempo": "neutral",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/9b559f3c-22e7-4b10-8158-3e11b333751e/dudleysaad/manifest.json",
#         "name": "Dudley",
#         "sample": "https://peregrine-results.s3.amazonaws.com/TzWYqWMTlbSF11bYhd.mp3",
#         "accent": "american",
#         "age": "old",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "low",
#         "style": "narrative",
#         "tempo": "fast",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/0c4c229f-7f99-4ed9-b904-223c701672b9/phoebesaad/manifest.json",
#         "name": "Phoebe",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/Phoebe.wav",
#         "accent": "british",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "videos",
#         "tempo": "fast",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/ff414883-0e32-4a92-a688-d7875922120d/original/manifest.json",
#         "name": "Autumn",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Autumn.wav",
#         "accent": "american",
#         "age": null,
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/a0fa25cc-5f42-4dd0-8a78-a950dd5297cd/original/manifest.json",
#         "name": "Isabella",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Isabella.wav",
#         "accent": "british",
#         "age": null,
#         "gender": "female",
#         "language": "English (GB)",
#         "language_code": "en-GB",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/509221d8-9e2d-486c-9b3c-97e52d86e63d/arthuradvertisingsaad/manifest.json",
#         "name": "Arthur (Advertising)",
#         "sample": "https://peregrine-results.s3.amazonaws.com/z05Mb3TymF75TcQnyV.mp3",
#         "accent": "british",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (GB)",
#         "language_code": "en-GB",
#         "loudness": "neutral",
#         "style": "advertising",
#         "tempo": "neutral",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/37e5af8b-800a-4a76-8f31-4203315f8a9e/billysaad/manifest.json",
#         "name": "Billy",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/billy.wav",
#         "accent": "american",
#         "age": null,
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": "gaming",
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/7447d346-20d5-4939-b43c-bdf17e757e98/cliftonsaad/manifest.json",
#         "name": "Clifton",
#         "sample": "https://peregrine-results.s3.amazonaws.com/IQqwyNGPmk3cF7x5QG.mp3",
#         "accent": "american",
#         "age": "old",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "gravelly",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/2a7ddfc5-d16a-423a-9441-5b13290998b8/novasaad/manifest.json",
#         "name": "Nova",
#         "sample": "https://peregrine-results.s3.amazonaws.com/H2u1NBpnzUYJD0pgDF.mp3",
#         "accent": "american",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "whisper",
#         "style": "narrative",
#         "tempo": "slow",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/dc90b58b-59a9-4e65-955d-c7620deb2d7a/original/manifest.json",
#         "name": "Richie",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Richie.wav",
#         "accent": "american",
#         "age": null,
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/7142f297-c55f-451d-8863-108d5101b5ed/susantrainingsaad/manifest.json",
#         "name": "Susan (Training)",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/susan+(training).wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "training",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/fd35d956-b644-4513-9cd0-7aa6931dfd43/juliansaad/manifest.json",
#         "name": "Julian",
#         "sample": "https://peregrine-results.s3.amazonaws.com/nHg2pd7S5L9ctKScRX.mp3",
#         "accent": "british",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (GB)",
#         "language_code": "en-GB",
#         "loudness": "neutral",
#         "style": "videos",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/bb759cd0-edb0-43d9-8273-f0a7c048fb11/original/manifest.json",
#         "name": "Lachlan",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Lachlan.wav",
#         "accent": "australian",
#         "age": null,
#         "gender": "male",
#         "language": "English (AU)",
#         "language_code": "en-AU",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/e46b4027-b38d-4d24-b292-38fbca2be0ef/original/manifest.json",
#         "name": "Atlas",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Atlas.wav",
#         "accent": "american",
#         "age": null,
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/aa753d26-bc20-479f-95af-5c3c1c970d93/original/manifest.json",
#         "name": "Finley",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Finley.wav",
#         "accent": "british",
#         "age": null,
#         "gender": "male",
#         "language": "English (GB)",
#         "language_code": "en-GB",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/74f59ea4-f07b-4d10-88d1-ca174adac3f3/original/manifest.json",
#         "name": "Pia",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Pia.wav",
#         "accent": "australian",
#         "age": null,
#         "gender": "female",
#         "language": "English (AU)",
#         "language_code": "en-AU",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/80ba8839-a6e6-470c-8f68-7c1e5d3ee2ff/abigailsaad/manifest.json",
#         "name": "Abigail",
#         "sample": "https://peregrine-results.s3.amazonaws.com/hbGWSpDCmbkVnEGmAl.mp3",
#         "accent": "american",
#         "age": null,
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": "narrative",
#         "tempo": null,
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/a72a5d4c-d729-4045-8bc8-1786043a4537/cartersaad/manifest.json",
#         "name": "Carter",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/carter.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "thick",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/f8af54e1-1534-4f68-ad8a-260cc132f820/original/manifest.json",
#         "name": "Nigel",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Nigel.wav",
#         "accent": "australian",
#         "age": null,
#         "gender": "male",
#         "language": "English (AU)",
#         "language_code": "en-AU",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/8ca8c44d-fb2b-4269-abca-4e6748a4a61e/arthursaad/manifest.json",
#         "name": "Arthur",
#         "sample": "https://peregrine-results.s3.amazonaws.com/B7H8TzHvhzdEd9XG3y.mp3",
#         "accent": "british",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/0a11e4f0-1656-48c9-bc4c-affcd718c414/madelynsaad/manifest.json",
#         "name": "Madelyn",
#         "sample": "https://peregrine-results.s3.amazonaws.com/hFF3qzi7zRuub0K9T7.mp3",
#         "accent": "british",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "videos",
#         "tempo": "fast",
#         "texture": "thick",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/087f79be-bb52-436a-93f3-cee27cd3b80d/huntersaad/manifest.json",
#         "name": "Hunter",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/hunter.wav",
#         "accent": "british",
#         "age": "old",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "narrative",
#         "tempo": "fast",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/f6c4ed76-1b55-4cd9-8896-31f7535f6cdb/original/manifest.json",
#         "name": "Aaliyah",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Aaliyah.wav",
#         "accent": "american",
#         "age": null,
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/5b81dc4c-bf98-469d-96b4-8f09836fb500/aurorasaad/manifest.json",
#         "name": "Aurora",
#         "sample": "https://peregrine-results.s3.amazonaws.com/CCxudBJ683rCXQviGa.mp3",
#         "accent": "british",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "low",
#         "style": "training",
#         "tempo": "slow",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/38a41ac2-f574-421c-adb9-ce1bcb6f4a84/arthurmeditationsaad/manifest.json",
#         "name": "Arthur (Meditation)",
#         "sample": "https://peregrine-results.s3.amazonaws.com/pigeon/1kdv17L92N1otdit39_0.mp3",
#         "accent": "british",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (GB)",
#         "language_code": "en-GB",
#         "loudness": "neutral",
#         "style": "meditation",
#         "tempo": "neutral",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/f669de94-fea6-4af3-a8ea-193b75bb142b/darrellsaad/manifest.json",
#         "name": "Darrell",
#         "sample": "https://peregrine-results.s3.amazonaws.com/AvIq3LAwQyaX4zKxfi.mp3",
#         "accent": "british",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "advertising",
#         "tempo": "neutral",
#         "texture": "thick",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/6c9c01b7-8d38-47ae-8ce5-18a360b26cf3/oliversaad/manifest.json",
#         "name": "Oliver",
#         "sample": "https://peregrine-results.s3.amazonaws.com/qLdehPTUSon46nCgzL.mp3",
#         "accent": "british",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "videos",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/b709b944-9256-4578-b9d8-a1ce4d729022/eileensaad/manifest.json",
#         "name": "Eileen",
#         "sample": "https://peregrine-results.s3.amazonaws.com/rtTTJKp1riEZnQQGgy.mp3",
#         "accent": "american",
#         "age": null,
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": "narrative",
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/e7e9514f-5ffc-4699-a958-3627151559d9/nolansaad2/manifest.json",
#         "name": "Nolan",
#         "sample": "https://peregrine-results.s3.amazonaws.com/c8PjtZ32eSYzWZDm3z.mp3",
#         "accent": "british",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "videos",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/5cd30986-f7f7-444b-ad82-d08ceb24ec5f/wilbertsaad/manifest.json",
#         "name": "Wilbert",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/wilbert.wav",
#         "accent": "british",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/32ae7ca0-634e-4fab-af74-0ec7c663e9da/original/manifest.json",
#         "name": "Leroy",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Leroy.wav",
#         "accent": "american",
#         "age": null,
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/3b7df114-e269-453a-8dc2-cbbce4c48f48/williamtrainingsaad/manifest.json",
#         "name": "William (Training)",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/William+(training).wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "training",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/92519089-3c97-4f31-8743-ab4f06047b88/larrysaad/manifest.json",
#         "name": "Larry (Narrative)",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/larry+(narrative).wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/8ceaa707-4141-46c0-a610-4a2014d7ea97/audreysaad/manifest.json",
#         "name": "Audrey",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/audrey.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "low",
#         "style": "narrative",
#         "tempo": "slow",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/72aafde0-8f4f-4a91-a483-21d76114ab17/original/manifest.json",
#         "name": "Ada",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Ada.wav",
#         "accent": "south african",
#         "age": null,
#         "gender": "male",
#         "language": "English (ZA)",
#         "language_code": "en-ZA",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/8007f637-9aec-4426-8c6a-7e713c032623/original/manifest.json",
#         "name": "Mitch",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Mitch.wav",
#         "accent": "australian",
#         "age": null,
#         "gender": "male",
#         "language": "English (AU)",
#         "language_code": "en-AU",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/2d5053ed-635a-499a-aa66-e85aeaf46d3e/darnellsaad/manifest.json",
#         "name": "Darnell",
#         "sample": "https://peregrine-results.s3.amazonaws.com/91d90mOYy97yxMzha5.mp3",
#         "accent": "american",
#         "age": "youth",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/483ed913-2817-45cb-b1a2-b79d9bfb2cf8/aylanarrativesaad/manifest.json",
#         "name": "Ayla (Narrative)",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/ayla+(narrative).wav",
#         "accent": "american",
#         "age": null,
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": "narrative",
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/640a6636-dc16-4911-b75a-1549daae2c71/original/manifest.json",
#         "name": "Lumi",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Lumi.wav",
#         "accent": "finnish",
#         "age": null,
#         "gender": "female",
#         "language": "English (FI)",
#         "language_code": "en-FI",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/261923bd-a10a-4a90-bced-0ce2b0230398/hooksaad/manifest.json",
#         "name": "Hook",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/hook.wav",
#         "accent": "american",
#         "age": null,
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": "gaming",
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/f43cc4b4-b193-4a13-a903-e6b125c3d572/original/manifest.json",
#         "name": "Luna",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Luna.wav",
#         "accent": "american",
#         "age": null,
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/a2852064-4b50-41a8-82f4-0ef0aae4601c/clarksaad/manifest.json",
#         "name": "Clark",
#         "sample": "https://peregrine-results.s3.amazonaws.com/GEFxhw1xJIoHksvjuY.mp3",
#         "accent": "british",
#         "age": "old",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "slow",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/4c627545-b9c0-4791-ae8e-f48f5475247c/bryansaad/manifest.json",
#         "name": "Bryan",
#         "sample": "https://peregrine-results.s3.amazonaws.com/euekNIyvT2kURh1CJ3.mp3",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "low",
#         "style": "videos",
#         "tempo": "fast",
#         "texture": "gravelly",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/75085d4f-839d-4ca5-a3e2-e329f04a591e/larrynarrativesaad/manifest.json",
#         "name": "Larry",
#         "sample": "https://peregrine-results.s3.amazonaws.com/LkIc6BF6Ivhf4GfR0T.mp3",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/90217770-a480-4a91-b1ea-df00f4d4c29d/original/manifest.json",
#         "name": "Samara",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Samara.wav",
#         "accent": "american",
#         "age": null,
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/1d26f4fe-1d08-4cfe-a7c1-d28e4e913ff9/original/manifest.json",
#         "name": "Baptiste",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Baptiste.wav",
#         "accent": "french",
#         "age": null,
#         "gender": "male",
#         "language": "English (FR)",
#         "language_code": "en-FR",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/07dc6825-4fde-4430-8c86-54ead89e0c88/donovansaad2/manifest.json",
#         "name": "Donovan",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/donovan.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "low",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/928ed0a0-2271-4710-a7c9-1711d36b9897/original/manifest.json",
#         "name": "Niamh",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Niamh.wav",
#         "accent": "irish",
#         "age": null,
#         "gender": "female",
#         "language": "English (IE)",
#         "language_code": "en-IE",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/72c255f8-00af-4c48-b0de-ad471baa3f52/alexsaad/manifest.json",
#         "name": "Alex",
#         "sample": "https://peregrine-results.s3.amazonaws.com/24TPOJX58Stixzl7GN.mp3",
#         "accent": "british",
#         "age": "old",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "narrative",
#         "tempo": "fast",
#         "texture": "thick",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/44f32760-8f41-4dfb-b192-ca077fc501ea/original/manifest.json",
#         "name": "Furio",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Furio.wav",
#         "accent": "italian",
#         "age": null,
#         "gender": "male",
#         "language": "English (IT)",
#         "language_code": "en-IT",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/7ced805f-611e-433c-8c43-568f48a8af4e/original/manifest.json",
#         "name": "Alessandro",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Alessandro.wav",
#         "accent": "italian",
#         "age": null,
#         "gender": "male",
#         "language": "English (IT)",
#         "language_code": "en-IT",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/ac9e2984-c7bb-44c8-8b6b-5c10728ad5cf/original/manifest.json",
#         "name": "Archie",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Archie.wav",
#         "accent": "australian",
#         "age": null,
#         "gender": "male",
#         "language": "English (AU)",
#         "language_code": "en-AU",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/b4a876c1-8730-435e-9595-141799868808/original/manifest.json",
#         "name": "Waylon",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Waylon.wav",
#         "accent": "american",
#         "age": null,
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/32b943f6-87cf-4e15-8e7a-d4cb848e3689/original/manifest.json",
#         "name": "Scarlett",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Scarlett.wav",
#         "accent": "british",
#         "age": null,
#         "gender": "female",
#         "language": "English (GB)",
#         "language_code": "en-GB",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/0ed97923-dd04-449f-a497-6f1109fdd9cc/jordansaad/manifest.json",
#         "name": "Jordan",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/jordan.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "training",
#         "tempo": "slow",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/f3600d9d-39ab-4494-b6ac-c6f5d122184d/original/manifest.json",
#         "name": "Teddy",
#         "sample": "https://parrot-samples.s3.amazonaws.com/gargamel/Teddy.wav",
#         "accent": "australian",
#         "age": null,
#         "gender": "male",
#         "language": "English (AU)",
#         "language_code": "en-AU",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://mockingbird-prod/abigail_vo_6661b91f-4012-44e3-ad12-589fbdee9948/voices/speaker/manifest.json",
#         "name": "Abigail",
#         "sample": "https://peregrine-samples.s3.us-east-1.amazonaws.com/editor-samples/abigail_vo.wav",
#         "accent": "american",
#         "age": null,
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": "narrative",
#         "tempo": null,
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "abram",
#         "name": "Abram",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/abram.wav",
#         "accent": "british",
#         "age": "old",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "low",
#         "style": "narrative",
#         "tempo": "slow",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "adolfo",
#         "name": "Adolfo",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/adolfo.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "fast",
#         "texture": "thick",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "adrian",
#         "name": "Adrian",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/Adrian.wav",
#         "accent": "american",
#         "age": "old",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "fast",
#         "texture": "thick",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/c00f7eb4-fbbd-4a7d-a4c5-ff57e92faf99/williamsaad3/manifest.json",
#         "name": "William",
#         "sample": "https://parrot-samples.s3.amazonaws.com/kettle/william.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "videos",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "alex",
#         "name": "Alex",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/alex.wav",
#         "accent": "british",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "narrative",
#         "tempo": "slow",
#         "texture": "thick",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "alexander",
#         "name": "Alexander",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/Alexander.wav",
#         "accent": "british",
#         "age": "old",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "narrative",
#         "tempo": "fast",
#         "texture": "thick",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "alfonso",
#         "name": "Alfonso",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/alfonso.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "videos",
#         "tempo": "neutral",
#         "texture": "gravelly",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "alphonso",
#         "name": "Alphonso",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/alphonso.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
# ...
#         "sample": null,
#         "accent": "british",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (GB)",
#         "language_code": "en-GB",
#         "loudness": "high",
#         "style": "training",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "s3://mockingbird-prod/olivia_vo_commercials_6e3c384f-15d6-4fe7-b9a4-0cb1d69daeba/voices/speaker/manifest.json",
#         "name": "Olivia (Advertising)",
#         "sample": "https://peregrine-samples.s3.us-east-1.amazonaws.com/editor-samples/olivia_vo_commercials.wav",
#         "accent": "canadian",
#         "age": null,
#         "gender": "female",
#         "language": "English (CA)",
#         "language_code": "en-CA",
#         "loudness": null,
#         "style": "advertising",
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "s3://peregrine-voices/olivia_ads3_parrot_saad/manifest.json",
#         "name": "Olivia (Narrative)",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/parrot-samples/olivia+narrative.wav",
#         "accent": "canadian",
#         "age": null,
#         "gender": "female",
#         "language": "English (CA)",
#         "language_code": "en-CA",
#         "loudness": null,
#         "style": "narrative",
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://mockingbird-prod/olivia_vo_training_4376204f-a411-4e5d-a5c0-ce6cc3908052/voices/speaker/manifest.json",
#         "name": "Olivia (Training)",
#         "sample": "https://peregrine-samples.s3.us-east-1.amazonaws.com/editor-samples/olivia_vo_training.wav",
#         "accent": "canadian",
#         "age": null,
#         "gender": "female",
#         "language": "English (CA)",
#         "language_code": "en-CA",
#         "loudness": null,
#         "style": "training",
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "oscar",
#         "name": "Oscar",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/oscar.wav",
#         "accent": "british",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "slow",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "owen",
#         "name": "Owen",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/Owen.wav",
#         "accent": "american",
#         "age": "youth",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "pedro",
#         "name": "Pedro",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/pedro.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "slow",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "phoebe",
#         "name": "Phoebe",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/Phoebe.wav",
#         "accent": "british",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "videos",
#         "tempo": "fast",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "randall",
#         "name": "Randall",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/randall.wav",
#         "accent": "british",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "narrative",
#         "tempo": "fast",
#         "texture": "thick",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "reynaldo",
#         "name": "Reynaldo",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/reynaldo.wav",
#         "accent": "british",
#         "age": "old",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "low",
#         "style": "narrative",
#         "tempo": "fast",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "rodrick",
#         "name": "Rodrick",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/rodrick.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/d9ff78ba-d016-47f6-b0ef-dd630f59414e/female-cs/manifest.json",
#         "name": "Ruby",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/parrot-samples/ruby.wav",
#         "accent": "australian",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (NZ)",
#         "language_code": "en-NZ",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://peregrine-voices/russell2_parrot_saad/manifest.json",
#         "name": "Russell",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/parrot-samples/russell.wav",
#         "accent": "australian",
#         "age": null,
#         "gender": "male",
#         "language": "English (AU)",
#         "language_code": "en-AU",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "gabriel",
#         "name": "Samantha",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/gabriel.wav",
#         "accent": "american",
#         "age": "old",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "thick",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "samuel",
#         "name": "Samuel",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/samuel.wav",
#         "accent": "american",
#         "age": "old",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "narrative",
#         "tempo": "slow",
#         "texture": "gravelly",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/820da3d2-3a3b-42e7-844d-e68db835a206/sarah/manifest.json",
#         "name": "Sarah",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/parrot-samples/sarah.wav",
#         "accent": "british",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (GB)",
#         "language_code": "en-GB",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "s3://mockingbird-prod/agent_47_carmelo_pampillonio_58e796e1-0b87-4f3e-8b36-7def6d65ce66/voices/speaker/manifest.json",
#         "name": "Sarge",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/sarge.wav",
#         "accent": "american",
#         "age": null,
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": "gaming",
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "s3://voice-cloning-zero-shot/1f44b3e7-22ea-4c2e-87d0-b4d9c8f1d47d/sophia/manifest.json",
#         "name": "Sophia",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/parrot-samples/sophia.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "stella",
#         "name": "Stella",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/Stella.wav",
#         "accent": "british",
#         "age": "old",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "training",
#         "tempo": "slow",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "susan",
#         "name": "Susan",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/susan.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "videos",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "s3://mockingbird-prod/susan_vo_commercials_0f4fa663-6eba-4582-be1e-2d5bde798f1c/voices/speaker/manifest.json",
#         "name": "Susan (Advertising)",
#         "sample": "https://peregrine-samples.s3.us-east-1.amazonaws.com/editor-samples/susan_vo_commercials.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "advertising",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "s3://mockingbird-prod/susan_vo_narrative_73051c90-460b-4e54-adab-9235f45c5e5f/voices/speaker/manifest.json",
#         "name": "Susan (Narrative)",
#         "sample": null,
#         "accent": "american",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "s3://mockingbird-prod/susan_vo_training_46ffcc60-d630-42f6-acfe-4affd003ae7a/voices/speaker/manifest.json",
#         "name": "Susan (Training)",
#         "sample": "https://peregrine-samples.s3.us-east-1.amazonaws.com/editor-samples/susan_vo_training.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "female",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "high",
#         "style": "training",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "theodore",
#         "name": "Theodore",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/Theodore.wav",
#         "accent": "american",
#         "age": "old",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "gravelly",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "wilbert",
#         "name": "Wilbert",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/wilbert.wav",
#         "accent": "british",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "wilbur",
#         "name": "Wilbur",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/wilbur.wav",
#         "accent": "american",
#         "age": "youth",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "wilfred",
#         "name": "Wilfred",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/wilfred.wav",
#         "accent": "american",
#         "age": "old",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "low",
#         "style": "training",
#         "tempo": "slow",
#         "texture": "smooth",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "s3://peregrine-voices/mel22/manifest.json",
#         "name": "Will",
#         "sample": null,
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": null,
#         "style": null,
#         "tempo": null,
#         "texture": null,
#         "is_cloned": false,
#         "voice_engine": "PlayHT2.0"
#     },
#     {
#         "id": "william",
#         "name": "William",
#         "sample": "https://peregrine-samples.s3.amazonaws.com/editor-samples/william_vo.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "videos",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "s3://mockingbird-prod/william_vo_narrative_0eacdff5-6243-4e26-8b3b-66e03458c1d1/voices/speaker/manifest.json",
#         "name": "William (Narrative)",
#         "sample": "https://peregrine-samples.s3.us-east-1.amazonaws.com/editor-samples/william_vo_narrative.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "narrative",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     },
#     {
#         "id": "s3://mockingbird-prod/william_vo_training_1b939b71-14fa-41f0-b1db-7d94f194ad0a/voices/speaker/manifest.json",
#         "name": "William (Training)",
#         "sample": "https://peregrine-samples.s3.us-east-1.amazonaws.com/editor-samples/william_vo_training.wav",
#         "accent": "american",
#         "age": "adult",
#         "gender": "male",
#         "language": "English (US)",
#         "language_code": "en-US",
#         "loudness": "neutral",
#         "style": "training",
#         "tempo": "neutral",
#         "texture": "round",
#         "is_cloned": false,
#         "voice_engine": "PlayHT1.0"
#     }
# ]
